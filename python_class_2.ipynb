# %% [markdown]
# <a href="https://colab.research.google.com/github/Anaanfathimat/python-class/blob/main/python_class_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pm=input("who is the pm of india? ")
print(pm)
# Out:
# who is the pm of india? Narendra Modi
# Narendra Modi

# %%
table=input("what is your table color? ")
print(table)
# Out:
# what is your table color? blue
# blue

# %%
mark=30
if mark>=25:print("you failed")
# Out:
# you failed

# %%
age=30
if age>=18:print("eligible to vote")
# Out:
# eligible to vote

# %%
student = {"name": "Anaan","age": 22,}

print(student["name"])
# Out:
# Anaan

# %%
Animal={"birds":["Paroot","sparrow", "crow", "eagle","duck"],"mammals":["elephant","whale","Lion","Tiger","dog"]}
print(Animal["birds"])
# Out:
# ['Paroot', 'sparrow', 'crow', 'eagle', 'duck']

# %%
def student(name="Anaan",age=22):
  print("name", name)
  print("age", age)
student()
# Out:
# name Anaan
# age 22

# %%
def student(name,age):
  print(name,age)
student("Anaan", 22)
# Out:
# Anaan 22

# %%
def cbs(**kwargs):
  print(kwargs)
cbs(name="Anaan", age=22, cource="MSc Econometrics and fintech")
# Out:
# {'name': 'Anaan', 'age': 22, 'cource': 'MSc Econometrics and fintech'}

# %%
# !pip install numpy
# !pip install pandas

# %%
import numpy as np
import numpy as pd
