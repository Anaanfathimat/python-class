# %% [markdown]
# <a href="https://colab.research.google.com/github/Anaanfathimat/python-class/blob/main/Sem_3_python_work_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1 + num2

print("Sum =", sum)
# Out:
# Enter first number: 5
# Enter second number: 6
# Sum = 11

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

product = num1 * num2

print("Product =", product)
# Out:
# Enter first number: 6
# Enter second number: 4
# Product = 24

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area of rectangle =", area)
# Out:
# Enter length: 7
# Enter width: 8
# Area of rectangle = 56.0

# %%
radius = float(input("Enter radius: "))

area = 3.14 * radius * radius

print("Area of circle =", area)
# Out:
# Enter radius: 4
# Area of circle = 50.24

# %%
mark1 = int(input("Enter mark 1: "))
mark2 = int(input("Enter mark 2: "))
mark3 = int(input("Enter mark 3: "))
mark4 = int(input("Enter mark 4: "))
mark5 = int(input("Enter mark 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5

print("Total Marks =", total)
# Out:
# Enter mark 1: 60
# Enter mark 2: 40
# Enter mark 3: 80
# Enter mark 4: 70
# Enter mark 5: 68
# Total Marks = 318

# %%
def hello():
    print("Hello CBS")

hello()
# Out:
# Hello CBS

# %%
def my_name():
    print("Anaan")

my_name()
# Out:
# Anaan

# %%
def square():
    print(10 ** 2)

square()
# Out:
# 100

# %%
def add():
    print(20 + 30)

add()
# Out:
# 50
