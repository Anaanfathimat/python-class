# %% [markdown]
# <a href="https://colab.research.google.com/github/Anaanfathimat/python-class/blob/main/python_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
movie="Avengers Endgame"
year="2019"
description="A group of superheroes unite to undo the damage caused by Thanos and restore balance to the universe."
print(f'My favourite movie is {movie}')
print(f'The movie was released in the year {year} ')
print(description)
# Out:
# My favourite movie is Avengers Endgame
# The movie was released in the year 2019
# A group of superheroes unite to undo the damage caused by Thanos and restore balance to the universe.

# %%
subject="Statistics"
description="it helps me analyze data, understand economic trends, and make informed decisions about real-world economic issues."
print(f'i like {subject} because {description}')
# Out:
# i like Statistics because it helps me analyze data, understand economic trends, and make informed decisions about real-world economic issues.

# %%
x=4
y=5
z=x+y
print(z)
# Out:
# 9

# %%
print(type(30))
print(type(32.5))
# Out:
# <class 'int'>
# <class 'float'>

# %%
age=int(21.4)
print(age)
# Out:
# 21

# %%
name="anaan"
print(name)
age=21
print(age)
favsubject="maths"
print(favsubject)
favcolour="red"
print(favcolour)
favfood="noodles"
print(favfood)
# Out:
# anaan
# 21
# maths
# red
# noodles

# %%
name=input("what is your name? ")
age=input("what is your age? ")
color=input("what is your favourite color? ")
hobby=input("what is your favourite hobby? ")
print(f'I am {name}, {age} years old.My favourite color is {color} and my favourite hobby is {hobby}.')
# Out:
# what is your name? Anaan
# what is your age? 21
# what is your favourite color? red
# what is your favourite hobby? watching movie
# I am Anaan, 21 years old.My favourite color is red  and my favourite hobby is watching movie.

# %%
# !git config --global user.email "anaanfathimat@gamil.com"
# !git config --global user.name "Anaanfathimat"
